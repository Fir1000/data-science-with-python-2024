# %%
import pandas as pd

# %%
df= pd.read_csv("/Users/fis008/Desktop/fundamental/data.csv")
df
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.describe()
# Out:
#                   id           Age  Academic Pressure  Work Pressure  \
# count   27901.000000  27901.000000       27901.000000   27901.000000
# mean    70442.149421     25.822300           3.141214       0.000430
# std     40641.175216      4.905687           1.381465       0.043992
# min         2.000000     18.000000           0.000000       0.000000
# 25%     35039.000000     21.000000           2.000000       0.000000
# 50%     70684.000000     25.000000           3.000000       0.000000
# 75%    105818.000000     30.000000           4.000000       0.000000
# max    140699.000000     59.000000           5.000000       5.000000
#
#                CGPA  Study Satisfaction  Job Satisfaction  Work/Study Hours  \
# count  27901.000000        27901.000000      27901.000000      27901.000000
# mean       7.656104            2.943837          0.000681          7.156984
# std        1.470707            1.361148          0.044394          3.707642
# ...

# %%
missing = df.isna().sum()
print(missing)
# Out:
# id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         3
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {'Month': ['Jan', 'Feb', 'Mar', 'Apr'],
        'Sales': [150, 200, 250, 300]}
df = pd.DataFrame(data)

# %%
plt.plot(df['Month'], df['Sales'], marker='o')  # Line graph with markers
plt.title('Monthly Sales')                      # Add a title
plt.xlabel('Month')                             # X-axis label
plt.ylabel('Sales')                             # Y-axis label
plt.grid(True)                                  # Add grid lines
plt.show()                                      # Display the graph

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = "/Users/fis008/Desktop/fundamental/data.csv"

df = pd.read_csv(file_path)

print("Columns:", df.columns)
print(df.head())

numerical_columns = df.select_dtypes(include='number').columns
if len(numerical_columns) >= 2:
    x_column = numerical_columns[0]
    y_column = numerical_columns[1]

    plt.plot(df[x_column], df[y_column], marker='o')
    plt.title(f"{x_column} vs {y_column}")
    plt.xlabel(x_column)
    plt.ylabel(y_column)
    plt.grid(True)
    plt.show()
else:
    print("No numerical columns found for plotting.")
# Out:
# Columns: Index(['id', 'Gender', 'Age', 'City', 'Profession', 'Academic Pressure',
#        'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction',
#        'Sleep Duration', 'Dietary Habits', 'Degree',
#        'Have you ever had suicidal thoughts ?', 'Work/Study Hours',
#        'Financial Stress', 'Family History of Mental Illness', 'Depression'],
#       dtype='object')
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# ...

# %%
print(df.columns)
# Out:
# Index(['id', 'Gender', 'Age', 'City', 'Profession', 'Academic Pressure',
#        'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction',
#        'Sleep Duration', 'Dietary Habits', 'Degree',
#        'Have you ever had suicidal thoughts ?', 'Work/Study Hours',
#        'Financial Stress', 'Family History of Mental Illness', 'Depression'],
#       dtype='object')

# %%
sns.histplot(df["id"], bins=10, kde=True, color="green")
# Out:
# <Axes: xlabel='id', ylabel='Count'>

# %%
sns.histplot(df["Gender"], bins=10, kde=True, color="red")
# Out:
# <Axes: xlabel='Gender', ylabel='Count'>

# %%
sns.histplot(df["Age"], bins=10, kde=True, color="orange")
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(df["City"], stat="density", kde=True)
# Out:
# <Axes: xlabel='City', ylabel='Density'>

# %%
sns.histplot(df["Academic Pressure"], discrete=10, kde=True, color="yellow")
# Out:
# <Axes: xlabel='Academic Pressure', ylabel='Count'>
